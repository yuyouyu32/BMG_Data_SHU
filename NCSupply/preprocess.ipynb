# %%
import pandas as pd

df = pd.read_excel('./NC判据论文数据.xlsx')
df['Alloy Systems'] = df['Alloy Systems'].apply(lambda x: ''.join(x.split(' ')[1:]) if x and ' ' in x else x)

# 查看结果
print(df)
# Out:
#                     Alloy Systems  T g(K)   TL(K)    trg          m  \
# 0               Ni69Cr8.5Nb3P19.5   660.0  1136.0  0.581       100#
# 1             Ni69Cr8.5Nb3P18B1.5   664.0  1134.0  0.586         77
# 2             Ni69Cr8.5Nb3P16.5B3   668.0  1134.0  0.589         59
# 3             Ni69Cr8.5Nb3P15.5B4   668.0  1187.0  0.563        NaN
# 4             Ni69Cr8.5Nb3P14.5B5   668.0  1214.0  0.550        NaN
# 5             Ni69Cr8.5Nb3P13.5B6   671.0  1243.0  0.540         54
# 6                         Ni80P20   581.0  1161.0  0.500    94 [22]
# 7                      Ni75Si8B17   818.0  1419.0  0.583       121*
# 8                       Fe80P13C7   736.0  1258.0  0.585       102*
# 9                   Fe40Ni40P14B6   662.0  1184.0  0.559     66 [9]
# 10                    Fe79Si10B11   818.0  1419.0  0.576        NaN
# 11         Fe74.5Mo5.5P12.5C5B2.5   695.0  1219.0  0.570    63 [15]
# 12       Fe68Mo5Ni5Cr2P12.5C5B2.5   688.0  1213.0  0.567         62
# ...

# %%
# 将更改后的DataFrame保存回Excel文件，如果需要
df.to_excel('NCSupply.xlsx', index=False)
